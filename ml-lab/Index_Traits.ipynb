# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('index_traits.csv')
df.drop(columns="Name", inplace=True)
df.columns = ["Index", "Starts", "End", "Duration", "Trait1", "Trait2", "Trait3", "Trait4", "Trait5", "Trait6", "Trait7"]
df.head()
# Out:
# Running cells with 'Python 3.13.13' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/popescu.victor/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'
